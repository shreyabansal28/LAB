# %%
import matplotlib.pyplot as plt
import seaborn as sn
import pandas as pd
bollywood_data_set = pd.read_csv('bollywood.csv')
bollywood_data_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149 entries, 0 to 148
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   SlNo                 149 non-null    int64
#  1   Release Date         149 non-null    object
#  2   MovieName            149 non-null    object
#  3   ReleaseTime          149 non-null    object
#  4   Genre                149 non-null    object
#  5   Budget               149 non-null    int64
#  6   BoxOfficeCollection  149 non-null    float64
#  7   YoutubeViews         149 non-null    int64
#  8   YoutubeLikes         149 non-null    int64
#  9   YoutubeDislikes      149 non-null    int64
# dtypes: float64(1), int64(5), object(4)
# memory usage: 11.8+ KB

# %%
plt.hist(bollywood_data_set['Budget'])
# Out:
# (array([64., 40., 19., 11.,  4.,  4.,  2.,  2.,  1.,  2.]),
#  array([  2. ,  16.8,  31.6,  46.4,  61.2,  76. ,  90.8, 105.6, 120.4,
#         135.2, 150. ]),
#  <BarContainer object of 10 artists>)

# %%
sn.distplot(bollywood_data_set['Budget'])
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_12312\2014452731.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(bollywood_data_set['Budget'])
# <Axes: xlabel='Budget', ylabel='Density'>
